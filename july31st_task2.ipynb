# %%
import pandas as pd

df1=pd.read_excel('C:/Users/Balakrishna/Downloads/Superstore_USA.xlsx')
df1.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df2=pd.read_excel('C:/Users/Balakrishna/Downloads/Superstore_USA.xlsx',sheet_name=1)
df2.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
#number of unique customers
len(df['Customer ID'].unique())
# Out:
# 2703

# %%
#concatanation of order and return data
df3=pd.concat([df1,df2])
df3.head()
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0  18606.0  Not Specified      0.01        2.88           0.50          2.0
# 1  20847.0           High      0.01        2.84           0.93          3.0
# 2  23086.0  Not Specified      0.03        6.68           6.15          3.0
# 3  23087.0  Not Specified      0.01        5.68           3.60          3.0
# 4  23088.0  Not Specified      0.00      205.99           2.50          3.0
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
df3.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID', 'Status'],
#       dtype='object')

# %%
# return that we ahve recived and with a product id
df3[df3['Status']=='Returned']['Order ID'].count()
# Out:
# 1634

# %%
# regions we are selling a product and who is a manager for a respective region \n",

df3['Region'].unique()
df3.groupby('Region')['Customer Name'].unique()
# Out:
# Region
# Central    [Janice Fletcher, Gwendolyn F Tyson, Marion No...
# East       [Leon Gill, Melanie Garner, Lorraine Houston, ...
# South      [Anne Nguyen, Lynn Morrow, Victoria Baker Hoov...
# West       [Bonnie Potter, Ronnie Proctor, Dwight Hwang, ...
# Name: Customer Name, dtype: object

# %%
# differnet shipement mode 
df5=df3['Ship Mode'].unique()
df5
# Out:
# array(['Regular Air', 'Express Air', 'Delivery Truck', nan], dtype=object)

# %%
#total orders
total=df3['Order ID'].count()
total
# Out:
# 11060

# %%
#percentage usablity of all the shipment mode with respect to datase
df4=df3.groupby('Ship Mode')['Order ID'].count()
df4
def percentage(a):
    
    percent=(a/total)*100
    print('ship mode is :',df5)
    print('shipment mode percentage is',percent)
for i in df4:
        percentage(i)
# Out:
# ship mode is : ['Regular Air' 'Express Air' 'Delivery Truck' nan]
# shipment mode percentage is 11.600361663652803
# ship mode is : ['Regular Air' 'Express Air' 'Delivery Truck' nan]
# shipment mode percentage is 10.009041591320072
# ship mode is : ['Regular Air' 'Express Air' 'Delivery Truck' nan]
# shipment mode percentage is 63.616636528028934

# %%
df4
# Out:
# Ship Mode
# Delivery Truck    1283
# Express Air       1107
# Regular Air       7036
# Name: Order ID, dtype: int64

# %%
# diffrence between order date and shipment date\n",
df3['difference']=df3['Ship Date']-df3['Order Date']
df3.head()
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0  18606.0  Not Specified      0.01        2.88           0.50          2.0
# 1  20847.0           High      0.01        2.84           0.93          3.0
# 2  23086.0  Not Specified      0.03        6.68           6.15          3.0
# 3  23087.0  Not Specified      0.01        5.68           3.60          3.0
# 4  23088.0  Not Specified      0.00      205.99           2.50          3.0
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#         City Postal Code Order Date  Ship Date    Profit Quantity ordered new  \
# ...

# %%
# order id we have shipment duration more than 10 days \n",

df3['Order ID'][df3['difference']>'10days']
# Out:
# 643     87215
# 1548    86318
# 1549    86318
# 1678    87957
# 1679    87957
# 1680    87957
# 1697    19556
# 1698    19556
# 1699    19556
# 2515    86177
# 5548    88223
# 5673    88352
# 5859    87572
# 5881    91294
# 8607    86434
# 8609    86436
# 8610    86436
# 8973    87300
# 8982    19841
# 8983    19841
# 8993    19841
# 8996    87300
# 8997    87300
# Name: Order ID, dtype: int64

# %%
#a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well \n",
df=(df3['Status']=='Returned'),(df3['difference']>'15days')
list(df)
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  1629     True
#  1630     True
#  1631     True
#  1632     True
#  1633     True
#  Name: Status, Length: 11060, dtype: bool,
#  0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  1629    False
#  1630    False
#  1631    False
#  1632    False
#  1633    False
#  Name: difference, Length: 11060, dtype: bool]

# %%
df7=df3['Customer Name'][df3['difference']>'15days'],(df3['Status']=='Returned')
df7
# Out:
# (643     Brenda Nelson Blanchard
#  1678         Christopher Bryant
#  1680         Christopher Bryant
#  1697                 Neal Wolfe
#  1699                 Neal Wolfe
#  2515            Virginia Rivera
#  5673               Carrie Boyle
#  5859              Lester Sawyer
#  5881                 Anna Glenn
#  8607                Jay Hubbard
#  8609                Jay Hubbard
#  8610                Jay Hubbard
#  8973              Earl Donnelly
#  8982               Peter Brooks
#  8983               Peter Brooks
#  8993               Peter Brooks
#  8996             Milton Harrell
#  8997             Milton Harrell
#  Name: Customer Name, dtype: object,
#  0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  1629     True
#  1630     True
#  1631     True
#  1632     True
#  1633     True
#  Name: Status, Length: 11060, dtype: bool)

# %%
def temp():
    for i in df7:
        return True
temp()
# Out:
# True

# %%
#. Gorup by region and find out which region is more profitable \
f1=df3.groupby('Region')['Profit'].sum()
f2=f1.max()
f2
for i in f1:
    if i==f2:
        print('region is :',i )
# Out:
# region is : 519825.56706659996

# %%
d1= df3.groupby('State or Province')['Discount'].sum()
d1
d2=d1.max()
d2
for i in d1:
    if i==d2:
        print('state or province is :',i )
# Out:
# state or province is : 52.28

# %%
#  a list of unique postal code
import numpy as np
arr=df3['Postal Code'].unique()
arr
from array import *
def array_list(array):
    num_list = array.tolist() # list
    print(num_list)
array_list(arr)
# Out:
# [60101.0, 98221.0, 91776.0, 95123.0, 2724.0, 3110.0, 8101.0, 8109.0, 7203.0, 2907.0, 55372.0, 11787.0, 13210.0, 59405.0, 59601.0, 59801.0, 68005.0, 10012.0, 92653.0, 92677.0, 92530.0, 92630.0, 90712.0, 93534.0, 90260.0, 97405.0, 97526.0, 97030.0, 97123.0, 97303.0, 62002.0, 98373.0, 98052.0, 75019.0, 23834.0, 62701.0, 60107.0, 60477.0, 14150.0, 12180.0, 77642.0, 75080.0, 77471.0, 78664.0, 75088.0, 24153.0, 94043.0, 92563.0, 94559.0, 10177.0, 2917.0, 5401.0, 4070.0, 2331.0, 8830.0, 8701.0, 7470.0, 7481.0, 5201.0, 97035.0, 44708.0, 45231.0, 44105.0, 95687.0, 5451.0, 94591.0, 70056.0, 22102.0, 60601.0, 66209.0, 66215.0, 66502.0, 66062.0, 6510.0, 4401.0, 4005.0, 2129.0, 2038.0, 1852.0, 1752.0, 2067.0, 3820.0, 8618.0, 7644.0, 7110.0, 8861.0, 7095.0, 2895.0, 97128.0, 97504.0, 98103.0, 84118.0, 84041.0, 93277.0, 76903.0, 78207.0, 60004.0, 94952.0, 1510.0, 1106.0, 1880.0, 6401.0, 6360.0, 2664.0, 15122.0, 76148.0, 5439.0, 5403.0, 37664.0, 37918.0, 37086.0, 37087.0, 80525.0, 80817.0, 60452.0, 7
# ...

# %%
arr=df3['Postal Code'].unique()
list(arr)
# Out:
# [60101.0,
#  98221.0,
#  91776.0,
#  95123.0,
#  2724.0,
#  3110.0,
#  8101.0,
#  8109.0,
#  7203.0,
#  2907.0,
#  55372.0,
#  11787.0,
#  13210.0,
#  59405.0,
#  59601.0,
#  59801.0,
#  68005.0,
#  10012.0,
#  92653.0,
#  92677.0,
#  92530.0,
#  92630.0,
#  90712.0,
#  93534.0,
#  90260.0,
#  97405.0,
#  97526.0,
#  97030.0,
#  97123.0,
#  97303.0,
#  62002.0,
#  98373.0,
#  98052.0,
#  75019.0,
#  23834.0,
#  62701.0,
#  60107.0,
#  60477.0,
#  14150.0,
#  12180.0,
#  77642.0,
#  75080.0,
#  77471.0,
#  78664.0,
#  75088.0,
#  24153.0,
#  94043.0,
#  92563.0,
#  94559.0,
#  10177.0,
#  2917.0,
#  5401.0,
#  4070.0,
#  2331.0,
#  8830.0,
#  8701.0,
#  7470.0,
#  7481.0,
#  5201.0,
#  97035.0,
#  44708.0,
#  45231.0,
#  44105.0,
#  95687.0,
#  5451.0,
#  94591.0,
#  70056.0,
#  22102.0,
#  60601.0,
#  66209.0,
#  66215.0,
#  66502.0,
#  66062.0,
#  6510.0,
#  4401.0,
#  4005.0,
#  2129.0,
#  2038.0,
#  1852.0,
#  1752.0,
#  2067.0,
#  3820.0,
#  8618.0,
#  7644.0,
#  7110.0,
# ...

# %%
#customer segement is more profitalble find it out
df3.groupby('Customer Segment')['Profit'].max()
# Out:
# Customer Segment
# Consumer           8118.8919
# Corporate         12504.9045
# Home Office       16332.4140
# Small Business    11429.4774
# Name: Profit, dtype: float64

# %%
#the 10th most loss making product catagory
df9=df3.sort_values(by='Profit')
df9.head()
df9.loc[9]['Product Category']
# Out:
# 9    Office Supplies
# 9                NaN
# Name: Product Category, dtype: object

# %%
#10 top  product with highest margins 
df10=df3.sort_values(by='Product Base Margin',ascending=False)
df10.head()
df10[0:10]['Product Name']
# Out:
# 9145                                          Accessory27
# 4756                                           Accessory4
# 7607                                          Accessory27
# 5672                                           Accessory4
# 4168                    Sterling Rubber Bands by Alliance
# 807                                           Accessory27
# 816                                           Accessory27
# 3994    Office Impressions Heavy Duty Welded Shelving ...
# 2138                    Sterling Rubber Bands by Alliance
# 7202    Office Impressions Heavy Duty Welded Shelving ...
# Name: Product Name, dtype: object
